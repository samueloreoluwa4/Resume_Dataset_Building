# %%
# importing modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Loading and Reading csv file
abdul = pd.read_csv("abdulbaqqi_work_experience.csv")
aishat = pd.read_csv("Aishat_Working_Experience.csv")
feranmi = pd.read_csv("Oluwaferanmi_WorkExperience.csv")
samuel = pd.read_csv("Samuel_Work_Experience.csv")
state = pd.read_csv("Statesman_work_experience.csv")
theo = pd.read_csv("TheophilusWork Experience.csv")

# %%
# Conveerting to a dataframe
abdul = pd.DataFrame(abdul)
abdul
# Out:
#         Unnamed: 0                 Job                Name of Organisation  \
# 0  worl experience  Internship Student  Harmony Advanced Diagnostic Centre
#
#   Year of Experience                                            Summary  \
# 0            3months  i worked with the radiographers to know how to...
#
#                         Top Achievement  Objective
# 0  operating some biomedical equipments        NaN

# %%
# Renaming columns and deleting columns
abdul1 = abdul.rename({"Name of Organisation":"Company_name", "Year of Experience":"Years_of_Experience", "Job":"Position", "Top Achievement":"Top_achievement", "Summary":"Work_summary", "Objective":"Work_objective"}, axis='columns')
del abdul1['Unnamed: 0']
abdul1
# Out:
#              Position                        Company_name Years_of_Experience  \
# 0  Internship Student  Harmony Advanced Diagnostic Centre             3months
#
#                                         Work_summary  \
# 0  i worked with the radiographers to know how to...
#
#                         Top_achievement  Work_objective
# 0  operating some biomedical equipments             NaN

# %%
# Comverting to dataframe
aishat = pd.DataFrame(aishat)
aishat
# Out:
#    Unnamed: 0   Name of company           postHeld Year of Experience
# 0           0  Temmy Enterprise  Computer Operator             1 year

# %%
# Renaming columns and deleting columns
aishat2 = aishat.rename({"Name of company":"Company_name", "postHeld":"Position", "Year of Experience":"Years_of_Experience"}, axis='columns')
del aishat2['Unnamed: 0']
aishat2
# Out:
#        Company_name           Position Years_of_Experience
# 0  Temmy Enterprise  Computer Operator              1 year

# %%
# Convering to dataframe
feranmi = pd.DataFrame(feranmi)
feranmi
# Out:
#    Job Title  Years Worked    Achievements
# 0        NaN           NaN  ['Awards', '']

# %%
# Renaming columns and deleting columns
feranmi4 = feranmi.rename({"Job Title":"Position", "Years Worked":"Years_of_Experience", "Achievements":"Top_achievement"}, axis='columns')
# Reasigning variable to column
feranmi4['Top_achievement'] = 'Awards'
feranmi4
# Out:
#    Position  Years_of_Experience Top_achievement
# 0       NaN                  NaN          Awards

# %%
# Converting to dataframe
samuel = pd.DataFrame(samuel)
samuel
# Out:
#    Unnamed: 0 Position                  Organisation  Year_spent  \
# 0           0  Teacher  Belgian International School           1
#
#   Top_achievement                                       Work_summary  \
# 0            None  Teaching, although hard but easy to practice. ...
#
#   Work_objective
# 0           None

# %%
# Renaming columns and deleting columns
samuel5 = samuel.rename({"Organisation":"Company_name", "Year_spent":"Years_of_Experience"}, axis='columns')
del samuel5['Unnamed: 0']
samuel5
# Out:
#   Position                  Company_name  Years_of_Experience Top_achievement  \
# 0  Teacher  Belgian International School                    1            None
#
#                                         Work_summary Work_objective
# 0  Teaching, although hard but easy to practice. ...           None

# %%
# Converting to dataframe
state = pd.DataFrame(state)
state
# Out:
#    Unnamed: 0                              Position Years of Experience  \
# 0           0  ['Research assistant, UPM, 5 years']             5 years
#
#                   Role summary  \
# 0  Perform research activities
#
#                                     Top Achievements  \
# 0  ['Published research that formed basis of a ne...
#
#                              Objective
# 0  To be a versatile Python programmer

# %%
# Renaming columns and deleting columns
state6 = state.rename({"Years of Experience":"Years_of_Experience", "Role summary":"Work_summary", "Top Achievements":"Top_achievement", "Objective":"Work_objective"}, axis='columns')
del state6['Unnamed: 0']
state6
# Out:
#                                Position Years_of_Experience  \
# 0  ['Research assistant, UPM, 5 years']             5 years
#
#                   Work_summary  \
# 0  Perform research activities
#
#                                      Top_achievement  \
# 0  ['Published research that formed basis of a ne...
#
#                         Work_objective
# 0  To be a versatile Python programmer

# %%
# Reasigning variables to their columns
state6['Position'] = ['Research assistant, UPM, 5 years']
state6['Top_achievement'] = ['Published research that formed basis of a new procedure in water treatment']
state6
# Out:
#                            Position Years_of_Experience  \
# 0  Research assistant, UPM, 5 years             5 years
#
#                   Work_summary  \
# 0  Perform research activities
#
#                                      Top_achievement  \
# 0  Published research that formed basis of a new ...
#
#                         Work_objective
# 0  To be a versatile Python programmer

# %%
# Reading full text of sentence
u = state6['Position'].all().split(", ")
u
# Out:
# ['Research assistant', 'UPM', '5 years']

# %%
state6['Position'] = u[0]
state6['Company_name'] = u[1]
state6 = pd.DataFrame(state6)
state6
# Out:
#              Position Years_of_Experience                 Work_summary  \
# 0  Research assistant             5 years  Perform research activities
#
#                                      Top_achievement  \
# 0  Published research that formed basis of a new ...
#
#                         Work_objective Company_name
# 0  To be a versatile Python programmer          UPM

# %%
# Converting to dataframe
theo = pd.DataFrame(theo)
theo
# Out:
#    Unnamed: 0  Job  Years of experience  Work summary  Top Achievements  \
# 0           0  NaN                  NaN           NaN               NaN
#
#                                       Work Objective
# 0  Hoping to be usefulbinthe mahine learning indu...

# %%
# Renaming columns and deleting columns
theo7 = theo.rename({"Job":"Position", "Years of experience":"Years_of_Experience", "Work summary":"Work_summary", "Top Achievements":"Top_achievement", "Work Objective":"Work_objective"}, axis='columns')
del theo7['Unnamed: 0']
theo7
# Out:
#    Position  Years_of_Experience  Work_summary  Top_achievement  \
# 0       NaN                  NaN           NaN              NaN
#
#                                       Work_objective
# 0  Hoping to be usefulbinthe mahine learning indu...

# %%
# Concatenating dataframes
Join = pd.concat([abdul1, aishat2, feranmi4, samuel5, state6, theo7], ignore_index=True, sort=False)
Join
# Out:
#              Position                        Company_name Years_of_Experience  \
# 0  Internship Student  Harmony Advanced Diagnostic Centre             3months
# 1   Computer Operator                    Temmy Enterprise              1 year
# 2                 NaN                                 NaN                 NaN
# 3             Teacher        Belgian International School                   1
# 4  Research assistant                                 UPM             5 years
# 5                 NaN                                 NaN                 NaN
#
#                                         Work_summary  \
# 0  i worked with the radiographers to know how to...
# 1                                                NaN
# 2                                                NaN
# 3  Teaching, although hard but easy to practice. ...
# 4                        Perform research activities
# 5                                                NaN
#
# ...

# %%
# To make Years of experience columns to be in integer (i.e oly number)
Join['Years_of_Experience'] = Join['Years_of_Experience'].fillna(0)
d = Join['Years_of_Experience']
d
# Out:
# 0    3months
# 1     1 year
# 2          0
# 3          1
# 4    5 years
# 5          0
# Name: Years_of_Experience, dtype: object

# %%
d[0] = int(d[0].strip('')[0])
d[0]
# Out:
# 3

# %%
d[1] = int(d[1].split(' ')[0])
d[1]
# Out:
# 1

# %%
d[4] = int(d[4].split(' ')[0])
d[4]
# Out:
# 5

# %%
d
# Out:
# 0    3
# 1    1
# 2    0
# 3    1
# 4    5
# 5    0
# Name: Years_of_Experience, dtype: object

# %%
Join
# Out:
#              Position                        Company_name Years_of_Experience  \
# 0  Internship Student  Harmony Advanced Diagnostic Centre                   3
# 1   Computer Operator                    Temmy Enterprise                   1
# 2                 NaN                                 NaN                   0
# 3             Teacher        Belgian International School                   1
# 4  Research assistant                                 UPM                   5
# 5                 NaN                                 NaN                   0
#
#                                         Work_summary  \
# 0  i worked with the radiographers to know how to...
# 1                                                NaN
# 2                                                NaN
# 3  Teaching, although hard but easy to practice. ...
# 4                        Perform research activities
# 5                                                NaN
#
# ...

# %%
# Sorting dataset according to the years of experience
data = Join.sort_values(by=['Years_of_Experience'])
data
# Out:
#              Position                        Company_name Years_of_Experience  \
# 2                 NaN                                 NaN                   0
# 5                 NaN                                 NaN                   0
# 1   Computer Operator                    Temmy Enterprise                   1
# 3             Teacher        Belgian International School                   1
# 0  Internship Student  Harmony Advanced Diagnostic Centre                   3
# 4  Research assistant                                 UPM                   5
#
#                                         Work_summary  \
# 2                                                NaN
# 5                                                NaN
# 1                                                NaN
# 3  Teaching, although hard but easy to practice. ...
# 0  i worked with the radiographers to know how to...
# 4                        Perform research activities
#
# ...

# %%
# FIlling NaN value with 'None'
data1 = data.fillna("None")
data1
# Out:
#              Position                        Company_name  \
# 2                None                                None
# 5                None                                None
# 1   Computer Operator                    Temmy Enterprise
# 3             Teacher        Belgian International School
# 0  Internship Student  Harmony Advanced Diagnostic Centre
# 4  Research assistant                                 UPM
#
#    Years_of_Experience                                       Work_summary  \
# 2                    0                                               None
# 5                    0                                               None
# 1                    1                                               None
# 3                    1  Teaching, although hard but easy to practice. ...
# 0                    3  i worked with the radiographers to know how to...
# 4                    5                        Perform research activities
#
# ...

# %%
data1.describe()
# Out:
#        Years_of_Experience
# count             6.000000
# mean              1.666667
# std               1.966384
# min               0.000000
# 25%               0.250000
# 50%               1.000000
# 75%               2.500000
# max               5.000000

# %%
# Making years of experience the subject of formula
data2 = data1.set_index('Years_of_Experience')
data2
# Out:
#                                Position                        Company_name  \
# Years_of_Experience
# 0                                  None                                None
# 0                                  None                                None
# 1                     Computer Operator                    Temmy Enterprise
# 1                               Teacher        Belgian International School
# 3                    Internship Student  Harmony Advanced Diagnostic Centre
# 5                    Research assistant                                 UPM
#
#                                                           Work_summary  \
# Years_of_Experience
# 0                                                                 None
# 0                                                                 None
# 1                                                                 None
# 1                    Teaching, although hard but easy to practice. ...
# ...
